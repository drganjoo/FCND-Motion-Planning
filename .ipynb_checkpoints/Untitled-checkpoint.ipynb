# %%
import planner
import planning_utils as u

# %%
wm = u.WorldMap()
wm.load()

g25 = wm.grid25
# Out:
# load_map: Home Position: Lat: 37.79248 Lon: -122.39745 Altitude 0
# load_map: Data North Min: -316, Max: 605
# load_map: Data East Min: -445, Max: 476

# %%
grid25 = g25.grid25
grid = g25.create_binary(5)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12, 12]

# %%
fig = plt.figure()
plt.imshow(grid, cmap='Greys', origin='lower')
plt.show()

# %%
data = np.loadtxt('colliders.csv', delimiter=',', dtype='Float64', skiprows=2)
print(np.amin(data[:, 0]))
# Out:
#   File "<ipython-input-14-f95fa7efccad>", line 2
#     print(np.amin(data[:, 0])
#                              ^
# SyntaxError: unexpected EOF while parsing
